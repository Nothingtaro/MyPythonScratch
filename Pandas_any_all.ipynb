# %% [markdown]
# ## Contents
# - [Comparison](#Comparison)
# - [Check for missing values](#Check-missing-values)

# %%
import pandas as pd

# %% [markdown]
# ## Mammal Sleep Data

# %%
df = pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/msleep.csv')
df
# Out:
#                           name       genus   vore         order  conservation  \
# 0                      Cheetah    Acinonyx  carni     Carnivora            lc
# 1                   Owl monkey       Aotus   omni      Primates           NaN
# 2              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 3   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 4                          Cow         Bos  herbi  Artiodactyla  domesticated
# ..                         ...         ...    ...           ...           ...
# 78                  Tree shrew      Tupaia   omni    Scandentia           NaN
# 79        Bottle-nosed dolphin    Tursiops  carni       Cetacea           NaN
# 80                       Genet     Genetta  carni     Carnivora           NaN
# 81                  Arctic fox      Vulpes  carni     Carnivora           NaN
# 82                     Red fox      Vulpes  carni     Carnivora           NaN
#
# ...

# %% [markdown]
# ## Comparison

# %%
df.sleep_total > 10
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
#       ...
# 78    False
# 79    False
# 80    False
# 81     True
# 82    False
# Name: sleep_total, Length: 83, dtype: bool

# %%
df[df.sleep_total > 10].head(5)
# Out:
#                          name       genus   vore         order conservation  \
# 0                     Cheetah    Acinonyx  carni     Carnivora           lc
# 1                  Owl monkey       Aotus   omni      Primates          NaN
# 2             Mountain beaver  Aplodontia  herbi      Rodentia           nt
# 3  Greater short-tailed shrew     Blarina   omni  Soricomorpha           lc
# 5            Three-toed sloth    Bradypus  herbi        Pilosa          NaN
#
#    sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# 0         12.1        NaN          NaN   11.9      NaN  50.000
# 1         17.0        1.8          NaN    7.0  0.01550   0.480
# 2         14.4        2.4          NaN    9.6      NaN   1.350
# 3         14.9        2.3     0.133333    9.1  0.00029   0.019
# 5         14.4        2.2     0.766667    9.6      NaN   3.850

# %%
(df.sleep_total > 10).any()
# Out:
# True

# %%
(df.sleep_total > 10).all()
# Out:
# False

# %%
(df.sleep_total > 10).sum()
# Out:
# 44

# %%
df[df.sleep_total > 10].any(axis=1).sum()
# Out:
# 44

# %%
df.sleep_total > df.awake
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
#       ...
# 78    False
# 79    False
# 80    False
# 81     True
# 82    False
# Length: 83, dtype: bool

# %%
(df.sleep_total > df.awake).any()
# Out:
# True

# %%
(df.sleep_total > df.awake).all()
# Out:
# False

# %%
(df.sleep_total > df.awake).sum()
# Out:
# 31

# %% [markdown]
# ## Check missing values

# %%
df
# Out:
#                           name       genus   vore         order  conservation  \
# 0                      Cheetah    Acinonyx  carni     Carnivora            lc
# 1                   Owl monkey       Aotus   omni      Primates           NaN
# 2              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 3   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 4                          Cow         Bos  herbi  Artiodactyla  domesticated
# ..                         ...         ...    ...           ...           ...
# 78                  Tree shrew      Tupaia   omni    Scandentia           NaN
# 79        Bottle-nosed dolphin    Tursiops  carni       Cetacea           NaN
# 80                       Genet     Genetta  carni     Carnivora           NaN
# 81                  Arctic fox      Vulpes  carni     Carnivora           NaN
# 82                     Red fox      Vulpes  carni     Carnivora           NaN
#
# ...

# %%
df.notna()
# Out:
#     name  genus  vore  order  conservation  sleep_total  sleep_rem  \
# 0   True   True  True   True          True         True      False
# 1   True   True  True   True         False         True       True
# 2   True   True  True   True          True         True       True
# 3   True   True  True   True          True         True       True
# 4   True   True  True   True          True         True       True
# ..   ...    ...   ...    ...           ...          ...        ...
# 78  True   True  True   True         False         True       True
# 79  True   True  True   True         False         True      False
# 80  True   True  True   True         False         True       True
# 81  True   True  True   True         False         True      False
# 82  True   True  True   True         False         True       True
#
#     sleep_cycle  awake  brainwt  bodywt
# 0         False   True    False    True
# 1         False   True     True    True
# ...

# %%
df.isna()
# Out:
#      name  genus   vore  order  conservation  sleep_total  sleep_rem  \
# 0   False  False  False  False         False        False       True
# 1   False  False  False  False          True        False      False
# 2   False  False  False  False         False        False      False
# 3   False  False  False  False         False        False      False
# 4   False  False  False  False         False        False      False
# ..    ...    ...    ...    ...           ...          ...        ...
# 78  False  False  False  False          True        False      False
# 79  False  False  False  False          True        False       True
# 80  False  False  False  False          True        False      False
# 81  False  False  False  False          True        False       True
# 82  False  False  False  False          True        False      False
#
#     sleep_cycle  awake  brainwt  bodywt
# 0          True  False     True   False
# 1          True  False    False   False
# ...

# %%
df.isna().any()
# Out:
# name            False
# genus           False
# vore             True
# order           False
# conservation     True
# sleep_total     False
# sleep_rem        True
# sleep_cycle      True
# awake           False
# brainwt          True
# bodywt          False
# dtype: bool

# %%
df.isna().sum()
# Out:
# name             0
# genus            0
# vore             7
# order            0
# conservation    29
# sleep_total      0
# sleep_rem       22
# sleep_cycle     51
# awake            0
# brainwt         27
# bodywt           0
# dtype: int64

# %%
(df.isna().sum()).sum()
# Out:
# 136

# %%
df[['name', 'genus']].notna().all()
# Out:
# name     True
# genus    True
# dtype: bool

# %%
df[['name', 'genus']].notna().sum()
# Out:
# name     83
# genus    83
# dtype: int64

# %%
df[['name', 'genus', 'vore']].notna().all()
# Out:
# name      True
# genus     True
# vore     False
# dtype: bool

# %%
df.isna()
# Out:
#      name  genus   vore  order  conservation  sleep_total  sleep_rem  \
# 0   False  False  False  False         False        False       True
# 1   False  False  False  False          True        False      False
# 2   False  False  False  False         False        False      False
# 3   False  False  False  False         False        False      False
# 4   False  False  False  False         False        False      False
# ..    ...    ...    ...    ...           ...          ...        ...
# 78  False  False  False  False          True        False      False
# 79  False  False  False  False          True        False       True
# 80  False  False  False  False          True        False      False
# 81  False  False  False  False          True        False       True
# 82  False  False  False  False          True        False      False
#
#     sleep_cycle  awake  brainwt  bodywt
# 0          True  False     True   False
# 1          True  False    False   False
# ...

# %%
df.isna().any(axis=1) # แถวนั้น ๆ มี missing values (na) อยู่หรือไม่
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4     False
#       ...
# 78     True
# 79     True
# 80     True
# 81     True
# 82     True
# Length: 83, dtype: bool

# %%
df[df.isna().any(axis=1)].head(5) # แถวที่มี missing values
# Out:
#                 name        genus   vore      order conservation  sleep_total  \
# 0            Cheetah     Acinonyx  carni  Carnivora           lc         12.1
# 1         Owl monkey        Aotus   omni   Primates          NaN         17.0
# 2    Mountain beaver   Aplodontia  herbi   Rodentia           nt         14.4
# 5   Three-toed sloth     Bradypus  herbi     Pilosa          NaN         14.4
# 6  Northern fur seal  Callorhinus  carni  Carnivora           vu          8.7
#
#    sleep_rem  sleep_cycle  awake  brainwt  bodywt
# 0        NaN          NaN   11.9      NaN   50.00
# 1        1.8          NaN    7.0   0.0155    0.48
# 2        2.4          NaN    9.6      NaN    1.35
# 5        2.2     0.766667    9.6      NaN    3.85
# 6        1.4     0.383333   15.3      NaN   20.49

# %%
df.notna().any(axis=1)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 78    True
# 79    True
# 80    True
# 81    True
# 82    True
# Length: 83, dtype: bool

# %%
df[df.notna().any(axis=1)].head(5) # แถวที่ไม่มี missing values
# Out:
#                          name       genus   vore         order  conservation  \
# 0                     Cheetah    Acinonyx  carni     Carnivora            lc
# 1                  Owl monkey       Aotus   omni      Primates           NaN
# 2             Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 3  Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 4                         Cow         Bos  herbi  Artiodactyla  domesticated
#
#    sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# 0         12.1        NaN          NaN   11.9      NaN   50.000
# 1         17.0        1.8          NaN    7.0  0.01550    0.480
# 2         14.4        2.4          NaN    9.6      NaN    1.350
# 3         14.9        2.3     0.133333    9.1  0.00029    0.019
# 4          4.0        0.7     0.666667   20.0  0.42300  600.000

# %%
df.vore.isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 78    False
# 79    False
# 80    False
# 81    False
# 82    False
# Name: vore, Length: 83, dtype: bool

# %%
df.vore.isna().all()
# Out:
# False

# %%
df.vore.notna().any()
# Out:
# True

# %%
df[['brainwt', 'awake']].notna().all(axis=1)
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4      True
#       ...
# 78     True
# 79    False
# 80     True
# 81     True
# 82     True
# Length: 83, dtype: bool

# %%
df[df[['brainwt', 'awake']].notna().all(axis=1)]
# Out:
#                               name         genus     vore            order  \
# 1                       Owl monkey         Aotus     omni         Primates
# 3       Greater short-tailed shrew       Blarina     omni     Soricomorpha
# 4                              Cow           Bos    herbi     Artiodactyla
# 8                              Dog         Canis    carni        Carnivora
# 9                         Roe deer     Capreolus    herbi     Artiodactyla
# 10                            Goat         Capri    herbi     Artiodactyla
# 11                      Guinea pig         Cavis    herbi         Rodentia
# 13                      Chinchilla    Chinchilla    herbi         Rodentia
# 14                 Star-nosed mole     Condylura     omni     Soricomorpha
# 15       African giant pouched rat    Cricetomys     omni         Rodentia
# 16       Lesser short-tailed shrew     Cryptotis     omni     Soricomorpha
# ...

# %%
df.notna().all() # (default axis=0) True = column contains no na value
# df.notna().all(axis=0) True = column contains no na/missing value
# Out:
# name             True
# genus            True
# vore            False
# order            True
# conservation    False
# sleep_total      True
# sleep_rem       False
# sleep_cycle     False
# awake            True
# brainwt         False
# bodywt           True
# dtype: bool

# %%
# แสดง columns ที่ไม่มี missing values
df.columns[df.notna().all()] # (default axis=0) True = column contains no na value
# Out:
# Index(['name', 'genus', 'order', 'sleep_total', 'awake', 'bodywt'], dtype='object')

# %%
# แสดง columns ที่มี missing values
df.columns[df.isna().any()] # (default axis=0) True = column contains no na value
# Out:
# Index(['vore', 'conservation', 'sleep_rem', 'sleep_cycle', 'brainwt'], dtype='object')
