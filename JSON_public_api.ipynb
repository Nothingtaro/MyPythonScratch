# %% [markdown]
# ## JSON RESTful APIs

# %% [markdown]
# 1. list of public APIs: https://github.com/public-apis/public-apis

# %%
import pandas as pd
from pandas.io.json import json_normalize
import json
import requests
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'

# %%
def get_api_result(url):
    r = requests.get(url)
    return json.loads(r.text)

# %% [markdown]
# ### Weather
# - https://www.metaweather.com/api/

# %%
url = 'https://www.metaweather.com/api/location/search/?query=bangkok'
j = get_api_result(url)
j
# Out:
# [{'title': 'Bangkok',
#   'location_type': 'City',
#   'woeid': 1225448,
#   'latt_long': '13.753330,100.504822'}]

# %%
j[0]['title']
# Out:
# 'Bangkok'

# %%
j[0]['latt_long']
# Out:
# '13.753330,100.504822'

# %%
j[0]['latt_long'].split(',')
# Out:
# ['13.753330', '100.504822']

# %%
url = 'https://www.metaweather.com/api/location/1225448'
j = get_api_result(url)
j
# Out:
# {'consolidated_weather': [{'id': 5045467114110976,
#    'weather_state_name': 'Heavy Rain',
#    'weather_state_abbr': 'hr',
#    'wind_direction_compass': 'S',
#    'created': '2021-07-12T01:36:20.683090Z',
#    'applicable_date': '2021-07-12',
#    'min_temp': 25.83,
#    'max_temp': 32.465,
#    'the_temp': 32.195,
#    'wind_speed': 4.061253809520401,
#    'wind_direction': 172.87951573731442,
#    'air_pressure': 1007.5,
#    'humidity': 77,
#    'visibility': 9.589932295394894,
#    'predictability': 77},
#   {'id': 6109083284275200,
#    'weather_state_name': 'Heavy Rain',
#    'weather_state_abbr': 'hr',
#    'wind_direction_compass': 'S',
#    'created': '2021-07-12T01:36:23.650362Z',
#    'applicable_date': '2021-07-13',
#    'min_temp': 26.11,
#    'max_temp': 31.939999999999998,
#    'the_temp': 32.215,
#    'wind_speed': 3.3905682545295477,
#    'wind_direction': 189.8074619732264,
#    'air_pressure': 1007.5,
#    'humidity': 72,
#    'visibility': 9.371209635727352,
# ...

# %% [markdown]
# ### Pokemon
# - https://pokeapi.co/

# %%
poke_name = 'rhydon'

url = f'https://pokeapi.co/api/v2/pokemon/{poke_name}'
j = get_api_result(url)
j
# Out:
# {'abilities': [{'ability': {'name': 'lightning-rod',
#     'url': 'https://pokeapi.co/api/v2/ability/31/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'rock-head',
#     'url': 'https://pokeapi.co/api/v2/ability/69/'},
#    'is_hidden': False,
#    'slot': 2},
#   {'ability': {'name': 'reckless',
#     'url': 'https://pokeapi.co/api/v2/ability/120/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 170,
#  'forms': [{'name': 'rhydon',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/112/'}],
#  'game_indices': [{'game_index': 1,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 1,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 1,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 112,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
# ...

# %%
j['abilities']
# Out:
# [{'ability': {'name': 'lightning-rod',
#    'url': 'https://pokeapi.co/api/v2/ability/31/'},
#   'is_hidden': False,
#   'slot': 1},
#  {'ability': {'name': 'rock-head',
#    'url': 'https://pokeapi.co/api/v2/ability/69/'},
#   'is_hidden': False,
#   'slot': 2},
#  {'ability': {'name': 'reckless',
#    'url': 'https://pokeapi.co/api/v2/ability/120/'},
#   'is_hidden': True,
#   'slot': 3}]
