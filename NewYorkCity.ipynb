# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

df = pd.read_csv("https://github.com/Nothingtaro/MyDataProject/raw/main/AB_NYC_2019.csv" 
                , index_col = 'id')
df.head()
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2539            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 2595           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3647           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3831            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5022           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48895 entries, 2539 to 36487245
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            48879 non-null  object
#  1   host_id                         48895 non-null  int64
#  2   host_name                       48874 non-null  object
#  3   neighbourhood_group             48895 non-null  object
#  4   neighbourhood                   48895 non-null  object
#  5   latitude                        48895 non-null  float64
#  6   longitude                       48895 non-null  float64
#  7   room_type                       48895 non-null  object
#  8   price                           48895 non-null  int64
#  9   minimum_nights                  48895 non-null  int64
#  10  number_of_reviews               48895 non-null  int64
#  11  last_review                     38843 non-null  object
# ...

# %%
df.describe()
# Out:
#             host_id      latitude     longitude         price  minimum_nights  \
# count  4.889500e+04  48895.000000  48895.000000  48895.000000    48895.000000
# mean   6.762001e+07     40.728949    -73.952170    152.720687        7.029962
# std    7.861097e+07      0.054530      0.046157    240.154170       20.510550
# min    2.438000e+03     40.499790    -74.244420      0.000000        1.000000
# 25%    7.822033e+06     40.690100    -73.983070     69.000000        1.000000
# 50%    3.079382e+07     40.723070    -73.955680    106.000000        3.000000
# 75%    1.074344e+08     40.763115    -73.936275    175.000000        5.000000
# max    2.743213e+08     40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48895.000000       38843.000000                    48895.000000
# mean           23.274466           1.373221                        7.143982
# ...

# %%
df1 = df.dropna()
df1.head()
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
# 5099         Large Cozy 1 BR Apartment In Midtown East     7322        Chris
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2539            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 2595           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3831            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5022           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
# 5099           Manhattan   Murray Hill  40.74767  -73.97500  Entire home/apt
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38821 entries, 2539 to 36455809
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            38821 non-null  object
#  1   host_id                         38821 non-null  int64
#  2   host_name                       38821 non-null  object
#  3   neighbourhood_group             38821 non-null  object
#  4   neighbourhood                   38821 non-null  object
#  5   latitude                        38821 non-null  float64
#  6   longitude                       38821 non-null  float64
#  7   room_type                       38821 non-null  object
#  8   price                           38821 non-null  int64
#  9   minimum_nights                  38821 non-null  int64
#  10  number_of_reviews               38821 non-null  int64
#  11  last_review                     38821 non-null  object
# ...

# %%
df1['host_id'] = df1['host_id'].astype(object)
# Out:
# <ipython-input-31-226d30452b59>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['host_id'] = df1['host_id'].astype(object)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38821 entries, 2539 to 36455809
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            38821 non-null  object
#  1   host_id                         38821 non-null  object
#  2   host_name                       38821 non-null  object
#  3   neighbourhood_group             38821 non-null  object
#  4   neighbourhood                   38821 non-null  object
#  5   latitude                        38821 non-null  float64
#  6   longitude                       38821 non-null  float64
#  7   room_type                       38821 non-null  object
#  8   price                           38821 non-null  int64
#  9   minimum_nights                  38821 non-null  int64
#  10  number_of_reviews               38821 non-null  int64
#  11  last_review                     38821 non-null  object
# ...

# %%
g = df1.groupby('neighbourhood_group')
g

# %%
g.groups
# Out:
# {'Bronx': [44096, 54626, 63610, 71812, 149777, 169306, 182177, 206071, 230854, 245544, 267535, 385824, 444430, 449680, 498120, 506575, 525293, 715270, 755528, 773041, 781486, 791452, 858695, 958444, 1026683, 1187643, 1278784, 1490223, 1693028, 1739847, 1747833, 1798500, 1934765, 1936633, 1956677, 2008227, 2062630, 2082328, 2223628, 2296024, 2392296, 2435198, 2545184, 2618288, 2628191, 2669366, 2719640, 2772111, 2814931, 2848235, 3039110, 3185829, 3191678, 3312276, 3400359, 3429765, 3431378, 3507112, 3627326, 3628328, 3655007, 3769052, 3790118, 3802218, 3839364, 3888469, 3939086, 3953314, 4031463, 4032229, 4039789, 4082062, 4093399, 4119763, 4278389, 4296710, 4407790, 4449559, 4456312, 4462008, 4472904, 4504049, 4632852, 4667707, 4671824, 4738429, 4795390, 4904582, 4963237, 4963511, 4967098, 5046189, 5288228, 5354796, 5458432, 5495927, 5749147, 5803068, 5824543, 5871372, ...], 'Brooklyn': [2539, 3831, 5121, 5803, 6848, 7097, 7726, 7801, 8024, 8025, 8110, 8490, 8505, 9782, 10452, 10962
# ...

# %%
g.get_group('Brooklyn')
# Out:
#                                                        name    host_id  \
# id
# 2539                     Clean & quiet apt home by the park       2787
# 3831                        Cozy Entire Floor of Brownstone       4869
# 5121                                        BlissArtsSpace!       7356
# 5803         Lovely Room 1, Garden, Best Area, Legal rental       9744
# 6848                       Only 2 stops to Manhattan studio      15991
# ...                                                     ...        ...
# 36310855  Room 3: Cozy Room w Large Closet & Light Break...  268394581
# 36351543              2-MONTH SUBLEASE (WITH EARLY MOVE-IN)   52984497
# 36390226             Comfortable clean Bedstuy private room  267932490
# 36413632         Spacious 2BR in Beautiful Brooklyn Heights    6608220
# 36455809            Cozy Private Room in Bushwick, Brooklyn   74162901
#
#               host_name neighbourhood_group       neighbourhood  latitude  \
# id
# ...

# %%
for k, v in g:
    print(k)
    print(v)
# Out:
# Bronx
#                                                        name    host_id  \
# id
# 44096                                      Room with a View     190409
# 54626                        Cozy bedroom by Yankee Stadium     190409
# 63610      DOMINIQUE'S NY mini efficiency* wifi*metro*quiet     310670
# 71812                  Condo Apartment with laundry in unit     369015
# 149777    Artsy 1 bedroom Apt. 20 min to 42nd Grand Cent...     716306
# ...                                                     ...        ...
# 36068351                                   The Emperors Den  252897042
# 36071960    Great Apartment only $79 per night \nGreat area  267710728
# 36108811              Bright and Sunny home away from home.  271616449
# 36206788                    Best 1 bedroom apartment in NYC  272308792
# 36442252                      1B-1B apartment near by Metro  273841667
#
#                         host_name neighbourhood_group   neighbourhood  \
# id
# ...

# %%
g.mean()
# Out:
#                       latitude  longitude       price  minimum_nights  \
# neighbourhood_group
# Bronx                40.848317 -73.883881   79.558857        3.932571
# Brooklyn             40.684796 -73.951028  121.463289        5.320153
# Manhattan            40.765975 -73.973898  180.071596        7.013477
# Queens               40.731381 -73.871199   95.783683        4.222441
# Staten Island        40.611207 -74.104838   89.964968        3.420382
#
#                      number_of_reviews  reviews_per_month  \
# neighbourhood_group
# Bronx                        32.381714           1.838549
# Brooklyn                     29.574427           1.283356
# Manhattan                    27.322423           1.271756
# Queens                       34.318023           1.941923
# Staten Island                36.754777           1.872580
#
#                      calculated_host_listings_count  availability_365
# neighbourhood_group
# ...

# %%
g.mean()[['price', 'number_of_reviews', 'reviews_per_month']]
# Out:
#                           price  number_of_reviews  reviews_per_month
# neighbourhood_group
# Bronx                 79.558857          32.381714           1.838549
# Brooklyn             121.463289          29.574427           1.283356
# Manhattan            180.071596          27.322423           1.271756
# Queens                95.783683          34.318023           1.941923
# Staten Island         89.964968          36.754777           1.872580

# %%
plt.figure(figsize=(10,10))
g.mean()['price'].plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='neighbourhood_group'>
